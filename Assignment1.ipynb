# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamS5/ML_Work/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd

# %%
train=pd.read_csv('/content/drive/MyDrive/Automobile_data (1).csv')

# %%
# Show basic information about the dataset (data types, non-null counts, etc.)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
train.describe() # Show descriptive statistics like mean, std, min, etc.
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
# Check for duplicates
duplicates = train[train.duplicated()]

# Display duplicates
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Drop duplicates
train = train.drop_duplicates()

print(f"Number of duplicates: {len(duplicates)}")
# Out:
# Number of duplicates: 0

# %%
import numpy as np

# Replace '?' with NaN
train.replace('?', np.nan, inplace=True)

# Check for missing values
missing_values = train.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Convert column to numeric (if necessary)
train['normalized-losses'] = pd.to_numeric(train ['normalized-losses'], errors='coerce')

# %%
# Calculate the mean of 'normalized-losses'
mean_normalized_losses = train['normalized-losses'].mean()

# Display the mean value
print("Mean of 'normalized-losses':", mean_normalized_losses)
# Out:
# Mean of 'normalized-losses': 122.0

# %%
train.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size  compression-ratio    city-mpg  \
# count  205.000000   205.000000   205.000000         205.000000  205.000000
# mean    53.724878  2555.565854   126.907317          10.142537   25.219512
# std      2.443522   520.680204    41.642693           3.972040    6.542142
# ...

# %%
#Check missing values in the 'price' column before dropping
missing_price_before = train['price'].isnull().sum()
print(f"Missing values in 'price' before drop: {missing_price_before}")
# Out:
# Missing values in 'price' before drop: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot boxplots to detect outliers
plt.figure(figsize=(10, 5))

# Boxplot for normalized-losses
plt.subplot(1, 2, 1)
sns.boxplot(data=train, x='normalized-losses')
plt.title('Boxplot of Normalized Losses')

# Boxplot for symboling
plt.subplot(1, 2, 2)
sns.boxplot(data=train, x='symboling')
plt.title('Boxplot of Symboling')

plt.show()

# %%
# Remove outliers using Interquartile Range (IQR)
Q1 = train['normalized-losses'].quantile(0.25)
Q3 = train['normalized-losses'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier condition
outliers_condition = (train['normalized-losses'] < (Q1 - 1.5 * IQR)) | (train['normalized-losses'] > (Q3 + 1.5 * IQR))

# Drop outliers
train = train[~outliers_condition]

# %%
# Plot without outliers (after removal)
plt.subplot(1, 2, 2)
sns.boxplot(data=df_cleaned, x='normalized-losses')
plt.title('Without Outliers')

plt.tight_layout()
plt.show()
